# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
import random
from collections import defaultdict

class BlackjackMCES:
    def __init__(self):
        self.Q = defaultdict(lambda: defaultdict(float))  # 状態-行動価値関数
        self.Returns = defaultdict(lambda: defaultdict(list))  # 報酬リスト
        self.policy = {}  # 方策（状態 -> 行動）

    def initialize_policy(self):
        """初期方策をランダムに設定"""
        for player_sum in range(12, 22):  # プレイヤーの手札合計（12~21）
            for dealer_card in range(1, 11):  # ディーラーの表向きカード（1~10）
                for usable_ace in [True, False]:  # エースの有無
                    state = (player_sum, dealer_card, usable_ace)
                    self.policy[state] = random.choice(["hit", "stick"])

    def draw_card(self):
        """カードを引く（1~10のランダムな値）"""
        return random.randint(1, 10)

    def calculate_hand(self, hand):
        """手札の合計値とエースの利用可否を計算"""
        total = sum(hand)
        if 1 in hand and total + 10 <= 21:
            return total + 10, True  # エースを11として使用可能
        return total, False

    def generate_episode(self):
        """エピソードを生成"""
        player_hand = [self.draw_card(), self.draw_card()]  # プレイヤーの初期手札
        dealer_hand = [self.draw_card(), self.draw_card()]  # ディーラーの初期手札

        player_sum, usable_ace = self.calculate_hand(player_hand)
        dealer_card = dealer_hand[0]

        episode = []
        while True:
            state = (player_sum, dealer_card, usable_ace)
            action = self.policy.get(state, "stick")  # 方策に基づく行動

            episode.append((state, action))

            if action == "stick":  # スティックで終了
                break

            player_hand.append(self.draw_card())
            player_sum, usable_ace = self.calculate_hand(player_hand)

            if player_sum > 21:  # バストで終了
                return episode, -1  # プレイヤーの負け

        # ディーラーのターン
        dealer_sum, _ = self.calculate_hand(dealer_hand)
        while dealer_sum < 17:
            dealer_hand.append(self.draw_card())
            dealer_sum, _ = self.calculate_hand(dealer_hand)

        # 勝敗判定
        if dealer_sum > 21 or player_sum > dealer_sum:
            return episode, 1  # プレイヤーの勝利
        elif player_sum < dealer_sum:
            return episode, -1  # ディーラーの勝利
        else:
            return episode, 0  # 引き分け

    def update_policy(self):
        """モンテカルロESで方策を更新"""
        for _ in range(1000):  # 1000エピソードを実行
            start_state = (random.randint(12, 21), random.randint(1, 10), random.choice([True, False]))
            start_action = random.choice(["hit", "stick"])
            self.policy[start_state] = start_action  # 探索的開始

            episode, reward = self.generate_episode()

            G = reward  # 累積報酬
            visited_pairs = set()
            for state, action in reversed(episode):
                if (state, action) not in visited_pairs:
                    visited_pairs.add((state, action))
                    self.Returns[state][action].append(G)
                    self.Q[state][action] = sum(self.Returns[state][action]) / len(self.Returns[state][action])
                    self.policy[state] = max(self.Q[state], key=self.Q[state].get)  # 方策改善

    def print_policy(self):
        """現在の方策を表示"""
        for state, action in self.policy.items():
            print(f"状態 {state}: 行動 {action}")

# 実行
if __name__ == "__main__":
    mc_es = BlackjackMCES()
    mc_es.initialize_policy()
    print("ブラックジャックでモンテカルロESを実行中...")
    mc_es.update_policy()
    print("\n最適化された方策:")
    mc_es.print_policy()
# Out:
# ブラックジャックでモンテカルロESを実行中...
#
# 最適化された方策:
# 状態 (12, 1, True): 行動 stick
# 状態 (12, 1, False): 行動 stick
# 状態 (12, 2, True): 行動 hit
# 状態 (12, 2, False): 行動 stick
# 状態 (12, 3, True): 行動 hit
# 状態 (12, 3, False): 行動 stick
# 状態 (12, 4, True): 行動 hit
# 状態 (12, 4, False): 行動 stick
# 状態 (12, 5, True): 行動 hit
# 状態 (12, 5, False): 行動 hit
# 状態 (12, 6, True): 行動 hit
# 状態 (12, 6, False): 行動 stick
# 状態 (12, 7, True): 行動 stick
# 状態 (12, 7, False): 行動 stick
# 状態 (12, 8, True): 行動 hit
# 状態 (12, 8, False): 行動 hit
# 状態 (12, 9, True): 行動 stick
# 状態 (12, 9, False): 行動 stick
# 状態 (12, 10, True): 行動 stick
# 状態 (12, 10, False): 行動 stick
# 状態 (13, 1, True): 行動 stick
# 状態 (13, 1, False): 行動 hit
# 状態 (13, 2, True): 行動 stick
# 状態 (13, 2, False): 行動 stick
# 状態 (13, 3, True): 行動 hit
# 状態 (13, 3, False): 行動 stick
# 状態 (13, 4, True): 行動 hit
# 状態 (13, 4, False): 行動 stick
# 状態 (13, 5, True): 行動 stick
# 状態 (13, 5, False): 行動 stick
# 状態 (13, 6, True): 行動 stick
# 状態 (13, 6, False): 行動 hit
# 状態 (13, 7, True): 行動 stick
# 状態 (13, 7, False): 行動 stick
# 状態 (13, 8, True): 行動 hit
# 状態 (13, 8, False): 行動 stick
# 状態 (13, 9, True): 行動 hit
# 状態 (13, 9, False): 行動 hit
# 状態 (13, 10, True): 行動 hit
# 状態 (13, 10, False): 行動 hit
# 状態 (14, 1, True): 行動 stick
# 状態 (14, 1, False): 行動 stick
# 状態 (14, 2, True): 行動 hit
# 状態 (14, 2, False): 行動 stick
# 状態 (14, 3, True): 行動 stick
# 状態 (14, 3, False): 行動 hit
# 状態 (14, 4, True): 行動 hit
# 状態 (14, 4, False): 行動 stick
# 状態 (14, 5, True): 行動 hit
# 状態 (14, 5, False): 行動 hit
# 状態 (14, 6, True): 行動 hit
# 状態 (14, 6, False): 行動 hit
# 状態 (14, 7, True): 行動 stick
# 状態 (14, 7, False): 行動 stick
# 状態 (14, 8, True): 行動 hit
# 状態 (14, 8, False): 行動 stick
# 状態 (14, 9, True): 行動 hit
# 状態 (14, 9, False): 行動 hit
# 状態 (14, 10, True): 行動 stick
# 状態 (14, 10, False): 行動 hit
# 状態 (15, 1, True): 行動 stick
# 状態 (15, 1, False): 行動 hit
# 状態 (15, 2, True): 行動 stick
# 状態 (15, 2, False): 行動 hit
# 状態 (15, 3, True): 行動 stick
# 状態 (15, 3, False): 行動 hit
# 状態 (15, 4, True): 行動 stick
# 状態 (15, 4, False): 行動 stick
# 状態 (15, 5, True): 行動 stick
# 状態 (15, 5, False): 行動 stick
# 状態 (15, 6, True): 行動 stick
# 状態 (15, 6, False): 行動 stick
# 状態 (15, 7, True): 行動 stick
# 状態 (15, 7, False): 行動 stick
# 状態 (15, 8, True): 行動 stick
# 状態 (15, 8, False): 行動 hit
# 状態 (15, 9, True): 行動 stick
# 状態 (15, 9, False): 行動 stick
# 状態 (15, 10, True): 行動 hit
# 状態 (15, 10, False): 行動 stick
# 状態 (16, 1, True): 行動 hit
# 状態 (16, 1, False): 行動 hit
# 状態 (16, 2, True): 行動 hit
# 状態 (16, 2, False): 行動 hit
# 状態 (16, 3, True): 行動 hit
# 状態 (16, 3, False): 行動 hit
# 状態 (16, 4, True): 行動 stick
# 状態 (16, 4, False): 行動 hit
# 状態 (16, 5, True): 行動 hit
# 状態 (16, 5, False): 行動 hit
# 状態 (16, 6, True): 行動 hit
# 状態 (16, 6, False): 行動 stick
# 状態 (16, 7, True): 行動 hit
# 状態 (16, 7, False): 行動 hit
# 状態 (16, 8, True): 行動 stick
# 状態 (16, 8, False): 行動 hit
# 状態 (16, 9, True): 行動 stick
# 状態 (16, 9, False): 行動 hit
# 状態 (16, 10, True): 行動 stick
# 状態 (16, 10, False): 行動 stick
# 状態 (17, 1, True): 行動 hit
# 状態 (17, 1, False): 行動 hit
# 状態 (17, 2, True): 行動 stick
# 状態 (17, 2, False): 行動 stick
# 状態 (17, 3, True): 行動 hit
# 状態 (17, 3, False): 行動 hit
# 状態 (17, 4, True): 行動 hit
# 状態 (17, 4, False): 行動 stick
# 状態 (17, 5, True): 行動 hit
# 状態 (17, 5, False): 行動 stick
# 状態 (17, 6, True): 行動 hit
# 状態 (17, 6, False): 行動 hit
# 状態 (17, 7, True): 行動 stick
# 状態 (17, 7, False): 行動 stick
# 状態 (17, 8, True): 行動 hit
# 状態 (17, 8, False): 行動 stick
# 状態 (17, 9, True): 行動 hit
# 状態 (17, 9, False): 行動 hit
# 状態 (17, 10, True): 行動 hit
# 状態 (17, 10, False): 行動 stick
# 状態 (18, 1, True): 行動 stick
# 状態 (18, 1, False): 行動 hit
# 状態 (18, 2, True): 行動 stick
# 状態 (18, 2, False): 行動 stick
# 状態 (18, 3, True): 行動 stick
# 状態 (18, 3, False): 行動 hit
# 状態 (18, 4, True): 行動 stick
# 状態 (18, 4, False): 行動 stick
# 状態 (18, 5, True): 行動 hit
# 状態 (18, 5, False): 行動 hit
# 状態 (18, 6, True): 行動 stick
# 状態 (18, 6, False): 行動 hit
# 状態 (18, 7, True): 行動 stick
# 状態 (18, 7, False): 行動 hit
# 状態 (18, 8, True): 行動 stick
# 状態 (18, 8, False): 行動 stick
# 状態 (18, 9, True): 行動 stick
# 状態 (18, 9, False): 行動 stick
# 状態 (18, 10, True): 行動 stick
# 状態 (18, 10, False): 行動 stick
# 状態 (19, 1, True): 行動 hit
# 状態 (19, 1, False): 行動 stick
# 状態 (19, 2, True): 行動 hit
# 状態 (19, 2, False): 行動 hit
# 状態 (19, 3, True): 行動 hit
# 状態 (19, 3, False): 行動 hit
# 状態 (19, 4, True): 行動 stick
# 状態 (19, 4, False): 行動 stick
# 状態 (19, 5, True): 行動 stick
# 状態 (19, 5, False): 行動 stick
# 状態 (19, 6, True): 行動 stick
# 状態 (19, 6, False): 行動 hit
# 状態 (19, 7, True): 行動 hit
# 状態 (19, 7, False): 行動 stick
# 状態 (19, 8, True): 行動 stick
# 状態 (19, 8, False): 行動 stick
# 状態 (19, 9, True): 行動 stick
# 状態 (19, 9, False): 行動 stick
# 状態 (19, 10, True): 行動 hit
# 状態 (19, 10, False): 行動 stick
# 状態 (20, 1, True): 行動 hit
# 状態 (20, 1, False): 行動 stick
# 状態 (20, 2, True): 行動 stick
# 状態 (20, 2, False): 行動 stick
# 状態 (20, 3, True): 行動 stick
# 状態 (20, 3, False): 行動 hit
# 状態 (20, 4, True): 行動 stick
# 状態 (20, 4, False): 行動 stick
# 状態 (20, 5, True): 行動 stick
# 状態 (20, 5, False): 行動 stick
# 状態 (20, 6, True): 行動 stick
# 状態 (20, 6, False): 行動 stick
# 状態 (20, 7, True): 行動 stick
# 状態 (20, 7, False): 行動 stick
# 状態 (20, 8, True): 行動 hit
# 状態 (20, 8, False): 行動 stick
# 状態 (20, 9, True): 行動 hit
# 状態 (20, 9, False): 行動 hit
# 状態 (20, 10, True): 行動 stick
# 状態 (20, 10, False): 行動 hit
# 状態 (21, 1, True): 行動 hit
# 状態 (21, 1, False): 行動 hit
# 状態 (21, 2, True): 行動 hit
# 状態 (21, 2, False): 行動 hit
# 状態 (21, 3, True): 行動 stick
# 状態 (21, 3, False): 行動 stick
# 状態 (21, 4, True): 行動 stick
# 状態 (21, 4, False): 行動 stick
# 状態 (21, 5, True): 行動 stick
# 状態 (21, 5, False): 行動 stick
# 状態 (21, 6, True): 行動 hit
# 状態 (21, 6, False): 行動 stick
# 状態 (21, 7, True): 行動 stick
# 状態 (21, 7, False): 行動 stick
# 状態 (21, 8, True): 行動 hit
# 状態 (21, 8, False): 行動 stick
# 状態 (21, 9, True): 行動 hit
# 状態 (21, 9, False): 行動 stick
# 状態 (21, 10, True): 行動 hit
# 状態 (21, 10, False): 行動 stick
# 状態 (10, 9, False): 行動 stick
# 状態 (7, 10, False): 行動 stick
# 状態 (10, 2, False): 行動 stick
# 状態 (9, 6, False): 行動 stick
# 状態 (5, 8, False): 行動 stick
# 状態 (11, 8, False): 行動 stick
# 状態 (9, 2, False): 行動 stick
# 状態 (6, 6, False): 行動 stick
# 状態 (9, 7, False): 行動 stick
# 状態 (11, 4, False): 行動 stick
# 状態 (10, 10, False): 行動 stick
# 状態 (10, 8, False): 行動 stick
# 状態 (10, 4, False): 行動 stick
# 状態 (6, 7, False): 行動 stick
# 状態 (8, 1, False): 行動 stick
# 状態 (11, 1, False): 行動 stick
# 状態 (7, 3, False): 行動 stick
# 状態 (11, 2, False): 行動 stick
# 状態 (9, 5, False): 行動 stick
# 状態 (8, 3, False): 行動 stick
# 状態 (5, 2, False): 行動 stick
# 状態 (9, 9, False): 行動 stick
# 状態 (4, 4, False): 行動 stick
# 状態 (5, 5, False): 行動 stick
# 状態 (8, 2, False): 行動 stick
# 状態 (7, 2, False): 行動 stick
# 状態 (6, 8, False): 行動 stick
# 状態 (7, 5, False): 行動 stick
# 状態 (11, 3, False): 行動 stick
# 状態 (9, 1, False): 行動 stick
# 状態 (10, 5, False): 行動 stick
# 状態 (6, 4, False): 行動 stick
# 状態 (9, 10, False): 行動 stick
# 状態 (8, 7, False): 行動 stick
# 状態 (9, 8, False): 行動 stick
# 状態 (11, 10, False): 行動 stick
# 状態 (6, 5, False): 行動 stick
# 状態 (7, 7, False): 行動 stick
# 状態 (7, 8, False): 行動 stick
# 状態 (5, 6, False): 行動 stick
# 状態 (10, 6, False): 行動 stick
# 状態 (10, 3, False): 行動 stick
# 状態 (11, 9, False): 行動 stick
# 状態 (9, 3, False): 行動 stick
# 状態 (6, 3, False): 行動 stick
# 状態 (8, 10, False): 行動 stick
# 状態 (11, 6, False): 行動 stick
# 状態 (6, 10, False): 行動 stick
# 状態 (8, 9, False): 行動 stick
# 状態 (10, 1, False): 行動 stick
# 状態 (11, 5, False): 行動 stick
# 状態 (8, 8, False): 行動 stick
# 状態 (7, 1, False): 行動 stick
# 状態 (5, 1, False): 行動 stick
# 状態 (9, 4, False): 行動 stick
# 状態 (5, 7, False): 行動 stick
# 状態 (11, 7, False): 行動 stick
# 状態 (8, 5, False): 行動 stick
# 状態 (6, 9, False): 行動 stick
# 状態 (6, 1, False): 行動 stick
# 状態 (7, 9, False): 行動 stick
# 状態 (7, 6, False): 行動 stick
# 状態 (8, 4, False): 行動 stick
# 状態 (5, 3, False): 行動 stick
# 状態 (4, 9, False): 行動 stick
# 状態 (5, 4, False): 行動 stick
# 状態 (4, 6, False): 行動 stick
# 状態 (7, 4, False): 行動 stick
# 状態 (10, 7, False): 行動 stick
# 状態 (8, 6, False): 行動 stick
# 状態 (4, 2, False): 行動 stick
